# %% [markdown]
# # RWDL Deep Learning part

# %% [markdown]
# ## Loading core libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline
from PIL import ImageFile
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import BatchNormalization, Conv2D, MaxPooling2D, Input, Conv2DTranspose
import cv2
import seaborn as sns
import tensorflow as tf
sns.set_style('darkgrid')

# %% [markdown]
# ## Declaration of basic constants

# %%
no_path = '../wm-nowm/train/no-watermark/'
water_path = '../wm-nowm/train/watermark/'
val_path_water = '../wm-nowm/valid/watermark/'
val_path_nowater = '../wm-nowm/valid/no-watermark/'
img_width, img_height = 64, 64
batch_size = 20
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %% [markdown]
# ## Base loading functions

# %%
def takeFileName(filedir): 
    filename = np.array(filedir.split('/'))[-1] 
    return filename

# %% [markdown]
# ### Function to search for images in selections that have an answer

# %%
def matchFileNames(watermarkedarr, nonwatermarkedarr, dname_wm, dname_nwm):
    sortedwmarr = np.array([])
    sortednwmarr = np.array([])
    
    wmarr = list(watermarkedarr)
    nwmarr = list(nonwatermarkedarr)
    
    length = len(watermarkedarr) if len(watermarkedarr) >= len(nonwatermarkedarr) else len(nonwatermarkedarr)
    
    for pos in range(length):
        try:
            if length == len(watermarkedarr): 
                exist_nwm = nwmarr.index(wmarr[pos])
                sortedwmarr = np.append(sortedwmarr, dname_wm + watermarkedarr[pos])
                sortednwmarr = np.append(sortednwmarr, dname_nwm + nonwatermarkedarr[exist_nwm]) 
            elif length == len(nonwatermarkedarr): 
                exist_wm = wmarr.index(nwmarr[pos])
                sortedwmarr = np.append(sortedwmarr, dname_wm + watermarkedarr[exist_wm])
                sortednwmarr = np.append(sortednwmarr, dname_nwm + nonwatermarkedarr[pos])
        except ValueError: 
            continue
    return sortedwmarr, sortednwmarr

# %% [markdown]
# ### Separation of images into training and test sets

# %%
tp_watermarked = np.array([]) 
tp_nonwatermarked = np.array([])

for root, dirs, files in os.walk(water_path, topdown=True): 
    for file in files:
        tp_watermarked = np.append(tp_watermarked, takeFileName(file)) 
    
for root, dirs, files in os.walk(no_path, topdown=True):
    for file in files:
        tp_nonwatermarked = np.append(tp_nonwatermarked, takeFileName(file)) 
        
tp_watermarked_sorted, tp_nonwatermarked_sorted = matchFileNames(tp_watermarked, tp_nonwatermarked, water_path, no_path)


val_watermarked = np.array([])
val_nonwatermarked = np.array([])

for root, dirs, files in os.walk(val_path_water, topdown=True): 
    for file in files:
        val_watermarked = np.append(val_watermarked, takeFileName(file))
    
for root, dirs, files in os.walk(val_path_nowater, topdown=True): 
    for file in files:
        val_nonwatermarked = np.append(val_nonwatermarked, takeFileName(file))
        
val_watermarked_sorted, val_nonwatermarked_sorted = matchFileNames(val_watermarked, val_nonwatermarked, val_path_water, val_path_nowater)

# %% [markdown]
# ### Create images from the database

# %%
def createPixelArr(files, width, height):
    data = []
    for image in files:
        try: # take each image and use imread to get the pixel values in a matrix 
            img_arr = cv2.imread(image, cv2.IMREAD_COLOR)
            resized_arr = cv2.resize(img_arr, (width, height)) # rescale the image so every image is of the same dimension
            data.append(resized_arr) # add the matrix of pixel values 
        except Exception as e:
            print(e)
    return np.array(data)

# %% [markdown]
# ## Creating a training sample

# %%
xTrain = createPixelArr(tp_watermarked_sorted, img_width, img_height)
yTrain = createPixelArr(tp_nonwatermarked_sorted, img_width, img_height)
xVal = createPixelArr(val_watermarked_sorted, img_width, img_height)
yVal = createPixelArr(val_nonwatermarked_sorted, img_width, img_height)

# %% [markdown]
# **Normalizing data**

# %%
xTrain = xTrain / 255
yTrain = yTrain / 255
xVal = xVal / 255
yVal = yVal / 255

# %%
val_dataset = tf.data.Dataset.from_tensor_slices((xVal, yVal))
val_dataset = val_dataset.batch(64)

# %%
plt.figure(figsize=(5,5))
for i in range(10):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(cv2.cvtColor(xVal[i].astype('float32'), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ## Autoencoder model

# %%
def baseAutoencoder(width, height):
    minWeight = width
    maxWeight = width * 2
    shape=(width, height, 3)
    img_input = Input((shape))

    x = Conv2D(minWeight, (3, 3), padding='same', activation='relu')(img_input)
    x = BatchNormalization()(x)
    x = Conv2D(minWeight, (3, 3), padding='same', activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D()(x)

    x = Conv2D(maxWeight, (3, 3), padding='same', activation='relu')(x)
    x = BatchNormalization()(x) 
    x = Conv2D(maxWeight, (3, 3), padding='same', activation='relu')(x)
    x = BatchNormalization()(x) 
    z = MaxPooling2D()(x)
    

    x = Conv2DTranspose(maxWeight, (2, 2), strides=(2, 2), padding='same', activation='relu')(z) # слой разжимает данные(с 28*20 на 56*40)
    x = BatchNormalization()(x)
    
    x = Conv2D(maxWeight, (3, 3), padding='same', activation='relu')(x)
    x = BatchNormalization()(x) 
    x = Conv2D(maxWeight, (3, 3), padding='same', activation='relu')(x)
    x = BatchNormalization()(x) 

    x = Conv2DTranspose(minWeight, (2, 2), strides=(2, 2), padding='same', activation='relu')(x) # слой разжимает данные(с 56*40 на 112*80)
    x = BatchNormalization()(x) 
    x = Conv2D(minWeight, (3, 3), padding='same', activation='relu')(x) 
    x = BatchNormalization()(x) 
    x = Conv2D(minWeight, (3, 3), padding='same', activation='relu')(x)
    x = BatchNormalization()(x) 

    x = Conv2D(shape[-1], (3, 3), activation='sigmoid', padding='same')(x)

    model = Model(img_input, x) # указываем модель, с оригинальным изображением на входе в сеть и сжатым-разжатым на выходе из сети
    model.compile(optimizer=Adam(lr=0.0001), loss='mean_squared_error') 

    return model

# %%
modelAutoEncoder = baseAutoencoder(img_width, img_height)

# %%
history = modelAutoEncoder.fit(xTrain, yTrain, epochs=200, batch_size=32, validation_data=val_dataset)
# Out:
# Epoch 1/200
# 55/55 [==============================] - 5s 79ms/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 2/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 3/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0039 - val_loss: 0.0041
# Epoch 4/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0041 - val_loss: 0.0043
# Epoch 5/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0039 - val_loss: 0.0041
# Epoch 6/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 7/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0038 - val_loss: 0.0040
# Epoch 8/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 9/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0039 - val_loss: 0.0041
# Epoch 10/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0039 - val_loss: 0.0041
# Epoch 11/200
# 55/55 [==============================] - 4s 76ms/step - loss: 0.0039 - val_loss: 0.0041
# Epoch 12/200
# 55/55 [==============================] - 4s 76ms/step - loss: 0.0040 - val_loss: 0.0042
# Epoch 13/200
# 55/55 [==============================] - 4s 75ms/step - loss: 0.0038 - val_loss: 0.0042
# Epoch 14/200
# 55/55 [==============================] - 4s 77ms/step - loss: 0.0038 - val_loss: 0.0042
# Epoch 15/200
# 55/55 [==============================] - 5s 87ms/step - loss: 0.0039 - val_loss: 0.0043
# Epoch 16/200
# 55/55 [==============================] - 4s 76ms/step - loss: 0.0038 - val_loss: 0.0040
# Epoch 17/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0037 - val_loss: 0.0040
# Epoch 18/200
# 55/55 [==============================] - 4s 67ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 19/200
# 55/55 [==============================] - 3s 62ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 20/200
# 55/55 [==============================] - 3s 62ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 21/200
# 55/55 [==============================] - 3s 61ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 22/200
# 55/55 [==============================] - 3s 62ms/step - loss: 0.0038 - val_loss: 0.0040
# Epoch 23/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 24/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 25/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 26/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0038 - val_loss: 0.0040
# Epoch 27/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 28/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0038 - val_loss: 0.0040
# Epoch 29/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 30/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0037 - val_loss: 0.0040
# Epoch 31/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 32/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 33/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 34/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0037 - val_loss: 0.0040
# Epoch 35/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 36/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 37/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 38/200
# 55/55 [==============================] - 4s 67ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 39/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 40/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 41/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 42/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 43/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 44/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0035 - val_loss: 0.0037
# Epoch 45/200
# 55/55 [==============================] - 4s 74ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 46/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0035 - val_loss: 0.0037
# Epoch 47/200
# 55/55 [==============================] - 4s 77ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 48/200
# 55/55 [==============================] - 4s 75ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 49/200
# 55/55 [==============================] - 4s 72ms/step - loss: 0.0034 - val_loss: 0.0038
# Epoch 50/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0034 - val_loss: 0.0038
# Epoch 51/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 52/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0035 - val_loss: 0.0037
# Epoch 53/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0035 - val_loss: 0.0037
# Epoch 54/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0034 - val_loss: 0.0037
# Epoch 55/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0034 - val_loss: 0.0039
# Epoch 56/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 57/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0033 - val_loss: 0.0038
# Epoch 58/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 59/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0034 - val_loss: 0.0037
# Epoch 60/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0034 - val_loss: 0.0037
# Epoch 61/200
# 55/55 [==============================] - 4s 75ms/step - loss: 0.0034 - val_loss: 0.0036
# Epoch 62/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0034 - val_loss: 0.0038
# Epoch 63/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0034 - val_loss: 0.0037
# Epoch 64/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 65/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 66/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0035 - val_loss: 0.0037
# Epoch 67/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0033 - val_loss: 0.0037
# Epoch 68/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0034 - val_loss: 0.0036
# Epoch 69/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0033 - val_loss: 0.0037
# Epoch 70/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 71/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0034 - val_loss: 0.0037
# Epoch 72/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 73/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 74/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 75/200
# 55/55 [==============================] - 4s 73ms/step - loss: 0.0034 - val_loss: 0.0194
# Epoch 76/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0039 - val_loss: 0.0050
# Epoch 77/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 78/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0034 - val_loss: 0.0038
# Epoch 79/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0034 - val_loss: 0.0037
# Epoch 80/200
# 55/55 [==============================] - 4s 76ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 81/200
# 55/55 [==============================] - 4s 67ms/step - loss: 0.0034 - val_loss: 0.0038
# Epoch 82/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 83/200
# 55/55 [==============================] - 4s 78ms/step - loss: 0.0035 - val_loss: 0.0036
# Epoch 84/200
# 55/55 [==============================] - 4s 79ms/step - loss: 0.0032 - val_loss: 0.0036
# Epoch 85/200
# 55/55 [==============================] - 4s 78ms/step - loss: 0.0032 - val_loss: 0.0038
# Epoch 86/200
# 55/55 [==============================] - 4s 72ms/step - loss: 0.0032 - val_loss: 0.0038
# Epoch 87/200
# 55/55 [==============================] - 4s 72ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 88/200
# 55/55 [==============================] - 3s 59ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 89/200
# 55/55 [==============================] - 3s 63ms/step - loss: 0.0031 - val_loss: 0.0036
# Epoch 90/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 91/200
# 55/55 [==============================] - 4s 79ms/step - loss: 0.0032 - val_loss: 0.0036
# Epoch 92/200
# 55/55 [==============================] - 4s 75ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 93/200
# 55/55 [==============================] - 4s 72ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 94/200
# 55/55 [==============================] - 5s 88ms/step - loss: 0.0031 - val_loss: 0.0035
# Epoch 95/200
# 55/55 [==============================] - 4s 74ms/step - loss: 0.0032 - val_loss: 0.0036
# Epoch 96/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 97/200
# 55/55 [==============================] - 4s 78ms/step - loss: 0.0031 - val_loss: 0.0035
# Epoch 98/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0031 - val_loss: 0.0035
# Epoch 99/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0031 - val_loss: 0.0036
# Epoch 100/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0031 - val_loss: 0.0036
# Epoch 101/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 102/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0031 - val_loss: 0.0036
# Epoch 103/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 104/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0031 - val_loss: 0.0036
# Epoch 105/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 106/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 107/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0031 - val_loss: 0.0035
# Epoch 108/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0031 - val_loss: 0.0035
# Epoch 109/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 110/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 111/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0030 - val_loss: 0.0036
# Epoch 112/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 113/200
# 55/55 [==============================] - 4s 73ms/step - loss: 0.0031 - val_loss: 0.0035
# Epoch 114/200
# 55/55 [==============================] - 4s 77ms/step - loss: 0.0031 - val_loss: 0.0036
# Epoch 115/200
# 55/55 [==============================] - 4s 73ms/step - loss: 0.0031 - val_loss: 0.0036
# Epoch 116/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 117/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 118/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 119/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 120/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0030 - val_loss: 0.0038
# Epoch 121/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 122/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 123/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 124/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 125/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 126/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 127/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 128/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0029 - val_loss: 0.0035
# Epoch 129/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 130/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0030 - val_loss: 0.0036
# Epoch 131/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 132/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 133/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 134/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0029 - val_loss: 0.0035
# Epoch 135/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 136/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0029 - val_loss: 0.0035
# Epoch 137/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 138/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 139/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 140/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 141/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 142/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 143/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 144/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 145/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 146/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 147/200
# 55/55 [==============================] - 4s 73ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 148/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0031 - val_loss: 0.0036
# Epoch 149/200
# 55/55 [==============================] - 4s 74ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 150/200
# 55/55 [==============================] - 4s 74ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 151/200
# 55/55 [==============================] - 4s 75ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 152/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 153/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0028 - val_loss: 0.0034
# Epoch 154/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 155/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 156/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 157/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0028 - val_loss: 0.0034
# Epoch 158/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0028 - val_loss: 0.0034
# Epoch 159/200
# 55/55 [==============================] - 4s 75ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 160/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 161/200
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0028 - val_loss: 0.0034
# Epoch 162/200
# 55/55 [==============================] - 4s 76ms/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 163/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0028 - val_loss: 0.0034
# Epoch 164/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 165/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 166/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0027 - val_loss: 0.0035
# Epoch 167/200
# 55/55 [==============================] - 4s 72ms/step - loss: 0.0028 - val_loss: 0.0035
# Epoch 168/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0028 - val_loss: 0.0034
# Epoch 169/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0028 - val_loss: 0.0035
# Epoch 170/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0028 - val_loss: 0.0034
# Epoch 171/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0027 - val_loss: 0.0034
# Epoch 172/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0031 - val_loss: 0.0134
# Epoch 173/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 174/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 175/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0029 - val_loss: 0.0035
# Epoch 176/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0028 - val_loss: 0.0035
# Epoch 177/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 178/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0029 - val_loss: 0.0035
# Epoch 179/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 180/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 181/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0027 - val_loss: 0.0037
# Epoch 182/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0028 - val_loss: 0.0034
# Epoch 183/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 184/200
# 55/55 [==============================] - 4s 73ms/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 185/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0026 - val_loss: 0.0034
# Epoch 186/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 187/200
# 55/55 [==============================] - 5s 84ms/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 188/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0028 - val_loss: 0.0034
# Epoch 189/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0027 - val_loss: 0.0032
# Epoch 190/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0027 - val_loss: 0.0034
# Epoch 191/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 192/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 193/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 194/200
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 195/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 196/200
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0027 - val_loss: 0.0034
# Epoch 197/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 198/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0027 - val_loss: 0.0034
# Epoch 199/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0027 - val_loss: 0.0032
# Epoch 200/200
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0026 - val_loss: 0.0033

# %%
modelAutoEncoder.save_weights('../weight/64.h5') # Сохраняем модель

# %%
modelAutoEncoder = baseAutoencoder(img_width, img_height)
modelAutoEncoder.load_weights('../weight/64.h5') # Загружаем модель

# %%
plt.figure(figsize=(7,3))
plt.plot(history.history['loss'][10:], 
         label='Average absolute error on the training set')
plt.ylabel('Average error')
plt.legend()
plt.show()

# %% [markdown]
# ## Look at the results of the test sample

# %%
res = modelAutoEncoder.predict(xVal)
modelAutoEncoder.evaluate(xVal, res)
# Out:
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0000e+00
# 0.0

# %%
plt.figure(figsize=(15,15))
for i in range(10):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(cv2.cvtColor(xVal[i].astype('float32'), cv2.COLOR_BGR2RGB))
plt.show()
plt.figure(figsize=(15,15))
for i in range(15):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(cv2.cvtColor(res[i], cv2.COLOR_BGR2RGB))
plt.show()
